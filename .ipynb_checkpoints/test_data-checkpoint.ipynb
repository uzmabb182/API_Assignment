# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
# Read in the csv data
weather_df = pd.read_csv('../output_data/cities.csv')
weather_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
city_state = weather_df[["City", "Country"]].iloc[0]
city_state
# Out:
# City       ostrovnoy
# Country           RU
# Name: 0, dtype: object

# %%
city = city_state[0]
city
# Out:
# 'ostrovnoy'

# %%
state = city_state[1]
state
# Out:
# 'RU'

# %%
Cities = weather_df['City']
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     548 non-null    int64
#  1   City        548 non-null    object
#  2   Cloudiness  548 non-null    int64
#  3   Country     544 non-null    object
#  4   Date        548 non-null    int64
#  5   Humidity    548 non-null    int64
#  6   Lat         548 non-null    float64
#  7   Lng         548 non-null    float64
#  8   Max Temp    548 non-null    float64
#  9   Wind Speed  548 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 42.9+ KB

# %%
df = weather_df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 544 entries, 0 to 547
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     544 non-null    int64
#  1   City        544 non-null    object
#  2   Cloudiness  544 non-null    int64
#  3   Country     544 non-null    object
#  4   Date        544 non-null    int64
#  5   Humidity    544 non-null    int64
#  6   Lat         544 non-null    float64
#  7   Lng         544 non-null    float64
#  8   Max Temp    544 non-null    float64
#  9   Wind Speed  544 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 46.8+ KB

# %%
df['Lat']
# Out:
# 0      68.05
# 1     -20.41
# 2      77.48
# 3      40.71
# 4     -33.93
#        ...
# 543    33.97
# 544    24.01
# 545    49.65
# 546    51.07
# 547    27.72
# Name: Lat, Length: 544, dtype: float64

# %%
df['Max Temp']
# Out:
# 0      37.50
# 1      78.80
# 2      22.20
# 3      44.60
# 4      55.99
#        ...
# 543    80.60
# 544    84.20
# 545    61.00
# 546    49.74
# 547    55.86
# Name: Max Temp, Length: 544, dtype: float64

# %%
# Create a Scatter Plot for temperature vs latitude

# %matplotlib notebook
import matplotlib.pyplot as plt

x_values = df['Lat']
y_values = df['Max Temp']
plt.scatter(x_values,y_values)
plt.title("Latitude Verses Temperature")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Create a Scatter Plot for Humidity vs latitude
# Dependencies and Setup
# %matplotlib notebook
import matplotlib.pyplot as plt

x_values = df['Lat']
y_values = df['Humidity']
plt.scatter(x_values,y_values)
plt.title("Latitude Verses Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# df2 = df.loc[((df['a'] > 1) & (df['b'] > 0)) | ((df['a'] < 1) & (df['c'] == 100))]

# %%
ideal_df = df.loc[(df['Max Temp'] < 80) & (df['Max Temp'] > 70) & (df['Wind Speed'] < 10) & (df['Cloudiness'] == 0)]
ideal_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 70        70  ponta do sol           0      BR  1558378767        57 -20.63
# 88        88      cidreira           0      BR  1558378770        66 -30.17
# 138      138     morondava           0      MG  1558378780        69 -20.30
# 139      139         vaini           0      IN  1558378780        88  15.34
# 176      176         nador           0      MA  1558378499        40  35.17
# 297      297         mogok           0      MM  1558378844        51  22.92
# 444      444       birjand           0      IR  1558378880        26  32.86
#
#        Lng  Max Temp  Wind Speed
# 70  -46.00     73.68        5.32
# 88  -50.22     76.56        5.50
# 138  44.28     79.08        9.06
# 139  74.49     78.90        1.59
# 176  -2.93     75.20        6.93
# 297  96.51     72.24        2.77
# 444  59.22     71.60        9.17

# %%
ideal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 70 to 444
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     7 non-null      int64
#  1   City        7 non-null      object
#  2   Cloudiness  7 non-null      int64
#  3   Country     7 non-null      object
#  4   Date        7 non-null      int64
#  5   Humidity    7 non-null      int64
#  6   Lat         7 non-null      float64
#  7   Lng         7 non-null      float64
#  8   Max Temp    7 non-null      float64
#  9   Wind Speed  7 non-null      float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 936.0+ bytes

# %%
# df_new = df.drop(df[(df['col_1'] == 1.0) & (df['col_2'] == 0.0)].index)

df_new = ideal_df.drop(ideal_df[(ideal_df['Max Temp'] < 80) & (ideal_df['Max Temp'] > 70) & (ideal_df['Cloudiness'] == 0)].index)
df_new
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
#cols = weather_df.select_dtypes(exclude=['float']).columns
#weather_df[cols] = weather_df[cols].apply(pd.to_numeric, downcast='float', errors='coerce')
#weather_df['Lat'] = weather_df['Lat'].astype(float, errors = 'raise')

#weather_df.info()

# %%
#for index, row in weather_df.iloc[:10].iterrows():
 #df = weather_df.dropna()
        #weather_df.drop(index, inplace=True)
        #weather_df.fillna(0, inplace=True)

# %%
# for i in x[:5]:
   # print i
# for city in cities[:5]:

# %%
# df1 = df[df.y <= 15]

# plt.plot(df.x,df.y, label="original")

# %%
x = lat_north_hem_df["Lat"]
y = lat_north_hem_df["Max_Temp"]

(m, b, rvalue, pvalue, stderr) = stats.linregress(x, y)

# Create line equation string
line_eq = (f"y = {m}x + {b}")
line_eq

y_calc = m*x+b

x_values = lat_north_hem_df["Lat"]
y_values = lat_north_hem_df["Max_Temp"]

# Compare the calcualted Pearson's r to the plots


correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
